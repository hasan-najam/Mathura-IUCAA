# %%
import pandas as pd

# %%
data = pd.read_csv('student.csv')
#data = pd.read_excel('Workshopdata.xls')

# %%
#!pip3 install pandas --upgrade

# %%
data
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head(8)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male

# %%
df.tail(9)
# Out:
#     id         name  class  mark  gender
# 26  27     Big Nose  Three    81  female
# 27  28    Rojj Base  Seven    86  female
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
# importing packages
import pandas as pd
import numpy as np
import pandas_profiling as pp


# dictionary of data
dct = {'ID': {0: 23, 1: 43, 2: 12, 3: 13,
			4: 67, 5: 89, 6: 90, 7: 56,
			8: 34},
	'Name': {0: 'Mudasir', 1: 'Farhan', 2: 'Asma',
				3: 'Aman', 4: 'Althaf', 5: 'Aditya',
				6: 'Humera', 7: 'Ramesh',
				8: 'Amer' },
	'Marks': {0: 89, 1: 97, 2: 45, 3: 78,
				4: 56, 5: 76, 6: 100, 7: 87,
				8: 81},
	'Grade': {0: 'B', 1: 'A', 2: 'F', 3: 'C',
				4: 'E', 5: 'C', 6: 'A', 7: 'B',
				8: 'B'}
	}

# forming dataframe and printing
data = pd.DataFrame(dct)
print(data)

# forming ProfileReport and save
# as output.html file
profile = pp.ProfileReport(data)
#profile.to_file("output.html")
# Out:
#    ID     Name  Marks Grade
# 0  23  Mudasir     89     B
# 1  43   Farhan     97     A
# 2  12     Asma     45     F
# 3  13     Aman     78     C
# 4  67   Althaf     56     E
# 5  89   Aditya     76     C
# 6  90   Humera    100     A
# 7  56   Ramesh     87     B
# 8  34     Amer     81     B

# %%
#!pip install pandas_profiling

# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp
dct = pd.read_csv('student.csv')
data = pd.DataFrame(dct)
print(data)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
# forming ProfileReport and save
# as output.html file
profile = pp.ProfileReport(data)
#profile.to_file("output2.html")
#profile

# %%
profile
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in _repr_html_(self)
#     395     def _repr_html_(self):
#     396         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 397         self.to_notebook_iframe()
#     398
#     399     def __repr__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_notebook_iframe(self)
#     375         with warnings.catch_warnings():
# ...

# %%
#!pip install xlrd
# Out:
# Keyring is skipped due to an exception: 'keyring.backends'
# ...

# %%
#df = pd.read_excel('Workshopdata.xls')
#print(df)
# Out:
#     Unnamed: 0 Unnamed: 1                             Unnamed: 2  \
# 0          NaN        NaN                                    NaN
# 1          NaN        NaN                                    NaN
# 2          NaN        NaN  GDP at constant prices US$ (2015=100)
# 3          NaN      Yeras                                 India
# 4          NaN       1960                    136368084184.195999
# ..         ...        ...                                    ...
# 61         NaN       2017                    2432015436983.77002
# 62         NaN       2018                   2588974097973.609863
# 63         NaN       2019                   2685747840248.319824
# 64         NaN       2020                   2508593750079.029785
# 65         NaN       2021                   2733061782358.359863
#
#                Unnamed: 3            Unnamed: 4            Unnamed: 5  \
# 0                     NaN                   NaN                   NaN
# ...

# %%
# !pip install ipywidgets
# Out:
# Keyring is skipped due to an exception: 'keyring.backends'
# ...

# %%
data = pd.DataFrame(df)
print(data)
# Out:
#     Unnamed: 0 Unnamed: 1                             Unnamed: 2  \
# 0          NaN        NaN                                    NaN
# 1          NaN        NaN                                    NaN
# 2          NaN        NaN  GDP at constant prices US$ (2015=100)
# 3          NaN      Yeras                                 India
# 4          NaN       1960                    136368084184.195999
# ..         ...        ...                                    ...
# 61         NaN       2017                    2432015436983.77002
# 62         NaN       2018                   2588974097973.609863
# 63         NaN       2019                   2685747840248.319824
# 64         NaN       2020                   2508593750079.029785
# 65         NaN       2021                   2733061782358.359863
#
#                Unnamed: 3            Unnamed: 4            Unnamed: 5  \
# 0                     NaN                   NaN                   NaN
# ...

# %%
profile = pp.ProfileReport(data)
profile.to_file("output3.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in _repr_html_(self)
#     395     def _repr_html_(self):
#     396         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 397         self.to_notebook_iframe()
#     398
#     399     def __repr__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_notebook_iframe(self)
#     375         with warnings.catch_warnings():
# ...
